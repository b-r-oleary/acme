# %% [markdown]
# # Interacting with our SQL Database
#
# This is a notebook introducing you to some code that I have written to access, save, and plot data obtained from the ACME logging database. This takes advantage of some code in `./code/database_access.py` and relies on a `pyodbc` database connection via an SQL server client.

# %%
# loading an ipython package to do section numbering
# %load_ext secnum
# %secnum
# Out:
# The secnum extension is already loaded. To reload it, use:
#   %reload_ext secnum

# %%
# %matplotlib inline
import sys
sys.path.append('./code')

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('poster')

from database_access import DatabaseAccess, load

# %% [markdown]
# ## Connecting to the Database
#
# The `DatabaseAccess` object creates a connection to the logging database and houses the `pyodbc` connection objects for the `LoggingConfigSQL` database and `LoggingLogData` database. In addition, there are a series of methods that are particular to our database structure that facilitate easier interactions with the database.
#
# In order to connect to the database, you must specify the IP address of the server. In this case Gandalf is located at `25.70.187.150` on the ACME VPN.

# %%
db = DatabaseAccess(server='25.70.187.150')
# Out:
# please enter the database password: ········
# LoggingConfigSQL connection open
# LoggingLogData connection open
# master connection open

# %% [markdown]
# The `logging_channels` method accesses the database and provides the full `LogChannelDetails` table in a pandas Dataframe. Below is a sample of that table.

# %%
db.logging_channels().head(2)
# Out:
#                LogChannelClassName     LogChannelGroupName  LogChannelID  \
# LogChannelName
# FG1x            Interaction Region  Fluxgate Magnetometers             1
# FG1y            Interaction Region  Fluxgate Magnetometers             2
#
#                                                  LogChannelInfo  \
# LogChannelName
# FG1x            Bartington Mag-03 Fluxgate Magnetometer Channel
# FG1y            Bartington Mag-03 Fluxgate Magnetometer Channel
#
#                ParameterTypeName  RoomName UnitName
# LogChannelName
# FG1x              Magnetic Field  LISE G14       mG
# FG1y              Magnetic Field  LISE G14       mG

# %% [markdown]
# You can also grab any other table in full by using the `get_table` method. Here is an example obtaining a list of the lasers in the lab.

# %%
db.get_table('LaserDetails', index='LaserName').head(3)
# Out:
#                             ComputerName  LaserID               LaserLockName  \
# LaserName
# 1064 Iodine Clock            No Computer        1  Iodine Modulation Transfer
# 690 Daredevil      G14 Laser Lock Feanor        2               Feanor Lock 1
# 690 Red Baron      G14 Laser Lock Feanor        3               Feanor Lock 1
#
#                   LaserLockReferenceName LaserLockReferenceTypeName  \
# LaserName
# 1064 Iodine Clock            Iodine Cell             Molecular Line
# 690 Daredevil            Feanor Cavity 1            Scanning Cavity
# 690 Red Baron            Feanor Cavity 1            Scanning Cavity
#
#                    LaserTypeName                LogChannelName       RoomName  \
# LaserName
# 1064 Iodine Clock         Nd:YAG  1064 Iodine Clock Wavenumber  Jefferson 162
# 690 Daredevil      ECDL Homemade      690 Daredevil Wavenumber       LISE G14
# 690 Red Baron      ECDL Homemade      690 Red Baron Wavenumber       LISE G14
#
#                    WavemeterChannel
# LaserName
# 1064 Iodine Clock                 0
# 690 Daredevil                    10
# 690 Red Baron                     2

# %% [markdown]
# ## Accessing Data
#
# Use the database command `get_data` to obtain data from logging channels and or groups. This command returns a `TimeSeriesArray` object that includes a `plot` method for simple plotting of the data. This object has a list of `TimeSeries` objects each of which correspond to a particular channel and have a timestamp array `t`, a data array `x`, and a channel properties field `channel`.
#
# Here is an example usage with a single channel - this is the vaccum pressure near the interactions region

# %%
ts = db.get_data('Dump Region Pressure', 
                 start_time=datetime(2016,2,16),
                 end_time=datetime(2016,2,22))
ts.plot()

# %% [markdown]
# Here is another example obtaining data from the last week of humidity data

# %%
tsa = db.get_data(group='Ambient Room Humidity', duration='1 week')
tsa.plot()

# %% [markdown]
# You can save the `TimeSeriesArray` objects to file as `.pkl` files which can be opened with the `load` function. If `load` is not provided a filename, it prompts the user to select a `.pkl` file from within the current working directory. After reloading the object, we can use it just as before - here we provide the example of accessing the array of channels which are included in this object.

# %%
tsa.save()
tsa = load()
tsa.channels()
# Out:
# saved: ./data/2016-02-21T18-28_2016-02-21T22-28_Stem_Pressure_Beam_Box_Pressure_Dump_Region_Pressure.pkl
# 0    ./data/2016-02-21T18-28_2016-02-21T22-28_Stem_...
# dtype: object
# input an integer corresponding to the file that you would like to load: 0
# loaded: ./data/2016-02-21T18-28_2016-02-21T22-28_Stem_Pressure_Beam_Box_Pressure_Dump_Region_Pressure.pkl
# ['Stem Pressure', 'Beam Box Pressure', 'Dump Region Pressure']

# %% [markdown]
# Sometimes you might be using this database access script to access the data, but you might not want to analyze the data in python. Under those circumstances, you may want to use the `save_to_text` function, which saves the data to a tab delimited txt file.

# %%
tsa.save_to_text()
# Out:
# saved: ./data/2016-02-21T18-28_2016-02-21T22-28_Stem_Pressure_Beam_Box_Pressure_Dump_Region_Pressure.txt

# %% [markdown]
# ## Accessing Control State Changes
#
# Above, we grabbed continuous logged data from the database and we plotted and saved it using the `TimeSeriesArray` object. In addition to continuous data, we also log discrete state changes in various experiment parameters that we call **controls**. We can perform analogous operations of grabbing and plotting this type of data using the `TimeSeriesStates` object which is provided by the database method `get_control_data`.
#
# Here is an example of getting all control state change data during the last 2 weeks from all controls within `LogControlClass='Beam Source'` (designated by keyword group).

# %%
tss = db.get_control_data(group='Beam Source', 
                          duration='2 weeks')
tss.plot(label_fontsize=12)

# %% [markdown]
# Here is another example obtaining all data from the last week - here some style modifications were made upon plotting so that the state labels didn't overlap

# %%
tss = db.get_control_data(duration='1 week')
tss.plot(wrap_length=100, label_fontsize=7)

# %% [markdown]
# ## Issuing General SQL Commands
#
# You can also issue general SQL commands and obtain responses in a pandas dataframe as follows:

# %%
db.sql_command("""SELECT * FROM information_schema.tables""", 
               database="LoggingLogData")
# Out:
#     TABLE_CATALOG                 TABLE_NAME TABLE_SCHEMA  TABLE_TYPE
# 0  LoggingLogData             LogChannelData          dbo  BASE TABLE
# 1  LoggingLogData        LogControlStateData          dbo  BASE TABLE
# 2  LoggingLogData                LogLabNotes          dbo  BASE TABLE
# 3  LoggingLogData            DopplerScanData          dbo  BASE TABLE
# 4  LoggingLogData               DopplerScans          dbo  BASE TABLE
# 5  LoggingLogData                     Header          dbo  BASE TABLE
# 6  LoggingLogData  AblationMirrorPositioning          dbo  BASE TABLE
# 7  LoggingLogData           LogProgramErrors          dbo  BASE TABLE

# %% [markdown]
# ## Ablation Mirror Positioning Maps
#
# We have a particular table, `AblationMirrorPositioning` that logs the location, time, and duration of ablation at a certain position on the ablation target. You can access that data via the particular `MapID` that corresponds to a given Map.

# %%
ab = db.get_ablation_map(38)
ab.print_report(edge_size=.0075)
ab.save()
# Out:
# saved: ./data/2014-10-03T21-00_2014-10-02T17-42_Ablation_Mirror_Map.pkl

# %% [markdown]
# ## Text File Database
#
# Most of the data that we deal with on a day to day basis is for smaller projects that may not be of interest to the group at large, at least at the time that it is generated. This data tends to be saved to text files, in various directories that only the creator of the data knows about, and the data formats tend to vary greatly for these applications such that it doesn't make sense to make a new set of database structures to hold that data for each application.
#
# My solution to this problem is to create a table inf `LoggingLogData` called `TextFileData` which can house these various types of data as they are generated. That way, we can have centrallized access to the various data types that we generate, but do not need new database structures to house them, so it is easy to contribute data and access it later.
#
# So that we know how to interpret each data format, I do enforce that you register a `DataType` in the `TextFileDataTypes` table on `LoggingLogData`. This can be performed by using the method `db.insert_text_file_data_type(datatype, description=None)` which takes a datatype string, and a text description of the formatting of the data. Also, if you try to insert a textfile into the database with a datatype that is not recognized, then you will be prompted to create a corresponding datatype.
#
# You can insert a textfile using the method `db.insert_text_file(title, datatype, text=None, header='', timestamp='now', filename=None)`. You must insert a title, a datatype, and a timestamp (this is a datetime object and defaults to datetime.datetime.now()). You can input either the `text` directly, or provide a path `filename` that points to the text that you would like to insert. The header field is optional - this can include additional notes about the conditions underwhich the data was taken.
#
# You can access the current datatypes using:

# %%
db.text_file_data_types()
# Out:
#                                                     DataTypeDescription  \
# DataType
# MIRG Interferometer   \nMIRG Interferometer Data Type:\n\neach measu...
# ExTorr Mass Spectrum        ExTorr RGA Spectrum filetype in xml format.
#
#                       DataTypeID
# DataType
# MIRG Interferometer            1
# ExTorr Mass Spectrum           2

# %% [markdown]
# Currently, there is only one datatype corresponding to the MIRG interferometer used to measure the separation between the field plates.
#
# You can access the current datafiles in the database using:

# %%
db.get_text_file_list(datatype='MIRG Interferometer', start_time=datetime(2016,3,23))
# Out:
#                    DataType           TimeStamp  \
# FileID
# 6       MIRG Interferometer 2016-03-23 12:50:35
# 7       MIRG Interferometer 2016-03-23 14:20:21
# 8       MIRG Interferometer 2016-03-23 15:53:52
# 9       MIRG Interferometer 2016-03-23 16:39:29
# 10      MIRG Interferometer 2016-03-23 18:15:28
# 11      MIRG Interferometer 2016-03-24 00:04:25
# 14      MIRG Interferometer 2016-03-23 00:00:11
# 15      MIRG Interferometer 2016-03-23 11:24:25
# 16      MIRG Interferometer 2016-03-23 12:04:49
#
#                                                     Title
# FileID
# 6       Gen II Field Plate Assembly with Gen II Plates...
# 7       Gen II Field Plate Assembly with Gen II Plates...
# 8       Gen II Field Plate Assembly with Gen II Plates...
# 9       Gen II Field Plate Assembly with Gen II Plates...
# 10                               Monitor Plate Relaxation
# 11                               Monitor Plate Relaxation
# 14      Gen II Field Plate Assembly with Gen II Plates...
# 15      Gen II Field Plate Assembly with Gen II Plates...
# 16      Gen II Field Plate Assembly with Gen II Plates...

# %% [markdown]
# And you can access full text files (organized by a dataframe) by using:

# %%
text_file = db.get_text_file(file_id=10)
text = text_file['Data'][0]
# here is a preview of the text data:
print(text[0:1800])
# Out:
#
# Interferometer Scan
# Wednesday, March 23, 2016	6:15:28 PM
# X position (cm)
# 0.000000
# Y position (cm)
# 0.000000
# Interferometer Positions (um)
# 5499.163500	5487.114375	5494.353375	5513.641500	5506.402500	5547.455250	5508.831375	5525.690625	5535.358500	5496.734625	5549.836500	5482.256625	5489.495625	5520.880500	5542.597500	5530.548375	5503.973625	5545.026375	5537.787375	5528.119500	5540.216250	5491.924500	5518.451625	5532.977250	5479.827750	5516.070375	5501.592375	5523.309375	5511.212625	5484.685500	5514.832125
# Fringe Signal
# 64.217761	3.934118	20.627790	294.490791	188.255415	2.644687	259.964431	52.235180	5.674802	35.090863	2.502514	2.831417	5.357094	143.282450	2.845020	16.752842	162.375811	2.754843	3.899265	27.638768	3.237368	11.502397	193.126794	10.143539	2.723314	243.581604	83.535730	91.867364	291.471599	3.111486	260.112177
# Laser Intensity Signal
# 48933.938135	36162.156626	58487.985930	37179.970028	58735.702835	58360.957501	37178.516439	58556.463186	58580.020756	58536.861368	58567.293665	36627.778109	36587.263754	37025.752023	36492.526223	58554.249380	27826.379817	49296.796549	58629.052170	36606.211523	49457.906319	49084.665692	37110.149284	58149.115003	58678.618358	59134.640128	49560.287969	59040.295813	59124.100628	58442.429235	37191.947387
# Gaussian Fit
# Amplitude   dAmplitude   Center   dCenter   Width   dWidth
# 282.955291	3.922481	5512.243680	0.122771	7.129974	0.122719

# %% [markdown]
# ## Finished? Close the Connection
#
# Its good practice to close the database connection when you are done accessing data:

# %%
db.close()
# Out:
# database connection closed
