# %% [markdown]
# # MIRG Interferometer Scans
#
# This notebook is used to perform analyses of MIRG interferometer scans

# %%
import sys

sys.path.append('./code')
from interferometer_data_manipulation import InterferometerData, InterferometerMap

# %matplotlib inline
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_context('poster')

# %%
Files = {'4.5 cm FP Scan after alignment June 2015':
    {'filename':'./data/2015_06-45mmFPSpacing/final_scans/Gen_II_set-up_with_Gen_I_plates_final_config_full_11-Interferometer Scan 6 3 2015.txt',
     'null_peak_position': 46484.5,
     'target':      45000},
        '2.5 cm FP Scan before disassembly February 2015':
    {'filename':['./data/2015_02-25mmFPSpacing/3/Long_Field_Plate_Scan_After_Adjustment-Interferometer Scan 2 13 2015.txt',
                './data/2015_02-25mmFPSpacing/3/Long_Field_Plate_Scan_After_Adjustment-Interferometer Scan 2 14 2015.txt'],
    'null_peak_position': 25400,
    'target': 25000},
         '2.5 cm FP Scan 2 February 2015':
    {'filename':['./data/2015_02-25mmFPSpacing/2/Second_Field_Plate_Scan-Interferometer Scan 2 12 2015.txt',
                './data/2015_02-25mmFPSpacing/2/Second_Field_Plate_Scan-Interferometer Scan 2 13 2015.txt'],
    'null_peak_position': 25400,
    'target': 25000},
        '4.5 cm Gen I FP Test February 2015':
    {'filename':['./data/2016-02-45mmFPSpacing/GenIFPTest/2016_02_04_GenI_FP_with_45mm_separation-Interferometer Scan 2 4 2016.txt'],
    'null_peak_position': 45954.429341,
    'target': 45000}
        }

# %%
# scan = '4.5 cm FP Scan after alignment June 2015'
# scan = '2.5 cm FP Scan before disassembly February 2015'
# scan = '2.5 cm FP Scan 2 February 2015'
scan = '4.5 cm Gen I FP Test February 2015'

scan_map = InterferometerMap.create_from_txt(Files[scan]['filename'], 
                                             null_peak_position=Files[scan]['null_peak_position'], 
                                             setpoint=Files[scan]['target'])
# Out:
#         :::::::::::::::Creating Interferometer Scan Map:::::::::::::::
#         importing scans from file and fitting the scans to gaussians.
#
# importing ./data/2016-02-45mmFPSpacing/GenIFPTest/2016_02_04_GenI_FP_with_45mm_separation-Interferometer Scan 2 4 2016.txt
# Completed in 2.40300011635 seconds.
#
# 2 interferometer scans were found to have had problems with fitting.
# 60 scans will be included in the map.
#
# the interferometer scan map has been created.

# %%
fig = scan_map.plot(max_line_length=170, h_angle=60, v_angle=40)
fig.savefig('./outputs/interferometer scan results - ' + scan + '.pdf')
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# C:\Anaconda\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):

# %%
scan_map.map
# Out:
# ::::::::::::::::::::::::: REGRESSION MODEL :::::::::::::::::::::::::
#
# label:			None
#
# type:			2d polynomial linear regression with 15 parameters
#
# model:			$s - 45000$ = a_{} + a_{$y$}$y$ + a_{$y$$^{2}$}$y$$^{2}$ + a_{$y$$^{3}$}$y$$^{3}$ + a_{$y$$^{4}$}$y$$^{4}$ + a_{$x$}$x$ + a_{$x$$y$}$x$$y$ + a_{$x$$y$$^{2}$}$x$$y$$^{2}$ + a_{$x$$y$$^{3}$}$x$$y$$^{3}$ + a_{$x$$^{2}$}$x$$^{2}$ + a_{$x$$^{2}$$y$}$x$$^{2}$$y$ + a_{$x$$^{2}$$y$$^{2}$}$x$$^{2}$$y$$^{2}$ + a_{$x$$^{3}$}$x$$^{3}$ + a_{$x$$^{3}$$y$}$x$$^{3}$$y$ + a_{$x$$^{4}$}$x$$^{4}$
#
# chi^2:			(7.66+/-0.21)
#
# error renormalized?:	True
#
# # datapoints:		60
#
# # outliers:		0
#
# coefficients:
#
#                      names                                     units  \
# 0                     a_{}                          $\mu \mathrm{m}$
# 1                  a_{$y$}      $\frac{\mu \mathrm{m}}{\mathrm{cm}}$
# 2            a_{$y$$^{2}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{2}}$
# 3            a_{$y$$^{3}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{3}}$
# 4            a_{$y$$^{4}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{4}}$
# 5                  a_{$x$}      $\frac{\mu \mathrm{m}}{\mathrm{cm}}$
# 6               a_{$x$$y$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{2}}$
# 7         a_{$x$$y$$^{2}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{3}}$
# 8         a_{$x$$y$$^{3}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{4}}$
# 9            a_{$x$$^{2}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{2}}$
# 10        a_{$x$$^{2}$$y$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{3}}$
# 11  a_{$x$$^{2}$$y$$^{2}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{4}}$
# 12           a_{$x$$^{3}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{3}}$
# 13        a_{$x$$^{3}$$y$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{4}}$
# 14           a_{$x$$^{4}$}  $\frac{\mu \mathrm{m}}{\mathrm{cm}^{4}}$
#
#        value    dvalue  significance   p(zero)
# 0  -6.661139  0.137670     48.384874  0.000000
# 1  -0.853954  0.060845     14.034919  0.000000
# 2  -0.073602  0.020440      3.600871  0.004747
# 3  -0.008133  0.003565      2.281486  0.289408
# 4   0.003079  0.000799      3.855645  0.001730
# 5   0.429909  0.020034     21.459450  0.000000
# 6  -0.071590  0.006124     11.690529  0.000000
# 7  -0.003384  0.001001      3.380466  0.010800
# 8  -0.000156  0.000223      0.696733  0.999954
# 9   0.059899  0.003260     18.373254  0.000000
# 10 -0.004212  0.000284     14.809796  0.000000
# 11  0.000401  0.000082      4.871257  0.000017
# 12  0.002105  0.000175     12.009983  0.000000
# 13 -0.000205  0.000038      5.353232  0.000001
# 14 -0.000038  0.000022      1.752335  0.712375
