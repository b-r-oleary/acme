# %%
# %matplotlib inline
import sys
sys.path.append('./code')

from molecule import State, Molecule
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import seaborn as sns
import numpy as np
sns.xkcd_palette
sns.set_style('white')
sns.set_context("poster")

# %%
fig13 = plt.figure()
ax13 = fig13.add_subplot(111, aspect='equal')
for p in [
    patches.FancyArrowPatch(
        (0.04, 0.2),
        (0.24, 0.8),
        connectionstyle='arc3',    # Default
        mutation_scale=20
    ),
    patches.FancyArrowPatch(
        (0.34, 0.2),
        (0.34, 0.8),
        connectionstyle='arc3, rad=0.7',
        mutation_scale=20
    ),
    patches.FancyArrowPatch(
        (0.74, 0.2),
        (0.94, 0.8),
        connectionstyle='arc3, rad=-0.5',
        mutation_scale=20
    ),
]:
    ax13.add_patch(p)

# %%
verts = [
    (0., 0.),  # P0
    (0.2, 1.), # P1
    (1., 0.8), # P2
    (0.8, 0.), # P3
    ]

codes = [Path.MOVETO,
         Path.CURVE4,
         Path.CURVE4,
         Path.CURVE4,
         ]

path = Path(verts, codes)

fig = plt.figure()
ax = fig.add_subplot(111)
patch = patches.PathPatch(path, facecolor='none', lw=2)
ax.add_patch(patch)

xs, ys = zip(*verts)
# ax.plot(xs, ys, 'x--', lw=2, color='black', ms=10)

# ax.text(-0.05, -0.05, 'P0')
# ax.text(0.15, 1.05, 'P1')
# ax.text(1.05, 0.85, 'P2')
# ax.text(0.85, -0.05, 'P3')

ax.set_xlim(-0.1, 1.1)
ax.set_ylim(-0.1, 1.1)
plt.show()

# %%
start = [0,1]
end   = [0,1]
plt.figure()
plt.plot(start,end,'ok')
plt.axis([-.5, 1.5, -.5, 1.5])

verts = [(0,0),
         ]
    
codes = [Path.MOVETO,
         Path.CURVE4,
         Path.CURVE4,
         Path.CURVE4,
         ]

path = Path(verts, codes)

fig = plt.figure()
ax = fig.add_subplot(111)
patch = patches.PathPatch(path, facecolor='none', lw=2)
ax.add_patch(patch)

xs, ys = zip(*verts)
# ax.plot(xs, ys, 'x--', lw=2, color='black', ms=10)

# ax.text(-0.05, -0.05, 'P0')
# ax.text(0.15, 1.05, 'P1')
# ax.text(1.05, 0.85, 'P2')
# ax.text(0.85, -0.05, 'P3')

ax.set_xlim(-0.1, 1.1)
ax.set_ylim(-0.1, 1.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-081c681aa490> in <module>()
#      14          ]
#      15
# ---> 16 path = Path(verts, codes)
#      17
#      18 fig = plt.figure()
#
# C:\Anaconda\lib\site-packages\matplotlib\path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     140             codes = np.asarray(codes, self.code_type)
#     141             assert codes.ndim == 1
# --> 142             assert len(codes) == len(vertices)
#     143             if len(codes):
#     144                 assert codes[0] == self.MOVETO
#
# AssertionError:

# %%
def generate_bezier_points(start, end, num = 10, width = .5):
    slope0 = (end[0] - start[0]) / (end[1] - start[1])
